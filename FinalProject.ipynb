# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

url = 'https://raw.githubusercontent.com/MattDee87/TheBeatles/main/TheBeatlesSongs.csv'
df1 = pd.read_csv(url, encoding_errors='ignore')

#showing all columns in df1
print(df1.columns)

#dropping unused columns in df1
df1.drop(df1.columns[[0, 6, 7, 8, 9, 10, 11]], axis = 1, inplace = True)

#columns used 
print(df1.columns)


#Beatles albums released by year
plt.plot(df1['year'], df1['album'])
plt.title('Beatles Albums Release by Year', fontdict={'fontweight':'bold'})
plt.xlabel('Year', fontsize=12)
plt.ylabel('Album', fontsize=12)
plt.figure(figsize=(6,4))

plt.show()

print()



#creating new dataframe called letbe from df1
letbe = df1[df1['album'] == 'Let It Be']

#Let It Be Album showing danceability by song 
plt.figure(figsize=(6,4))
plt.title('Let It Be', fontdict={'fontweight':'bold'})
plt.xlabel('Danceability', fontsize=12)
plt.ylabel('Song', fontsize=12)

plt.scatter(letbe['danceability'], letbe['song'])

plt.show()

#finding highest danceability song from letbe dataframe 
max = letbe ['danceability'].max()

maxdf = letbe[letbe['danceability'] == max]

#display top dance song
print('Dance Score:', max, ':', 'For You Blue')
print()



#creating new dataframe called abbey from df1
abbey = df1[df1['album'] == 'Abbey Road']

#Abbey Road Album showing dancability by song
plt.figure(figsize=(6,4))
plt.title('Abbey Road', fontdict={'fontweight':'bold'})
plt.xlabel('Danceability', fontsize=12)
plt.ylabel('Song', fontsize=12)

plt.scatter(abbey['danceability'], abbey['song'])

plt.show()

#finding highest danceability song from abbey dataframe 
max = abbey ['danceability'].max()

maxdf = pd.concat([maxdf,abbey[abbey['danceability'] == max]])

#display top dance song
print('Dance Score:', max, ':', 'Maxwells Silver Hammer')
print()



#creating new dataframe called yellow from df1
yellow = df1[df1['album'] == 'Yellow Submarine']

#Yellow Submarine Album showing dancability by song
plt.figure(figsize=(6,4))
plt.title('Yellow Submarine', fontdict={'fontweight':'bold'})
plt.xlabel('Danceability', fontsize=12)
plt.ylabel('Song', fontsize=12)

plt.scatter(yellow['danceability'], yellow['song'])

plt.show()

#finding highest danceability song from yellow dataframe 
max = yellow ['danceability'].max()

maxdf = pd.concat([maxdf,yellow[yellow['danceability'] == max]])

#display top dance song
print('Dance Score:', max, ':', 'Yellow Submarine')
print()



#creating new dataframe called white from df1
white = df1[df1['album'] == 'The Beatles (white album)']

#The Beatles (white album) Album showing dancability by song
plt.figure(figsize=(12,9))
plt.title('The Beatles (white album)', fontdict={'fontweight':'bold'})
plt.xlabel('Danceability', fontsize=12)
plt.ylabel('Song', fontsize=12)

plt.scatter(white['danceability'], white['song'])

plt.show()

#finding highest danceability song from white dataframe 
max = white ['danceability'].max()

maxdf = pd.concat([maxdf,white[white['danceability'] == max]])

#display top dance song
print('Dance Score:', max, ':', 'Obi-la-di, Ob-la-da')
print()



#creating new dataframe called magical from df1
magical = df1[df1['album'] == 'Magical Mystery Tour']

#Magical Mystery Tour Album showing dancability by song
plt.figure(figsize=(6,4))
plt.title('Magical Mystery Tour', fontdict={'fontweight':'bold'})
plt.xlabel('Danceability', fontsize=12)
plt.ylabel('Song', fontsize=12)

plt.scatter(magical['danceability'], magical['song'])

plt.show()

#finding highest danceability song from magical dataframe 
max = magical ['danceability'].max()

maxdf = pd.concat([maxdf,magical[magical['danceability'] == max]])

#display top dance song
print('Dance Score:', max, ':', 'Your Mother Should Know')
print()



#creating new dataframe called sgt from df1
sgt = df1[df1['album'] == 'Sgt. Pepper\'s Lonely Hearts Club Band']

#Sgt. Peppers Lonely Hearts Club Band Album showing dancability by song
plt.figure(figsize=(6,4))
plt.title('Sgt. Pepper\'s Lonely Hearts Club Band', fontdict={'fontweight':'bold'})
plt.xlabel('Danceability', fontsize=12)
plt.ylabel('Song', fontsize=12)

plt.scatter(sgt['danceability'], sgt['song'])

plt.show()

#finding highest danceability song from sgt dataframe
max = sgt ['danceability'].max()

maxdf = pd.concat([maxdf,sgt[sgt['danceability'] == max]])

#display top dance song
print('Dance Score:', max, ':', 'With a Little Help from My Friends')
print()



#creating new dataframe called revolver from df1
revolver = df1[df1['album'] == 'Revolver']

#Revolver Album showing dancability by song
plt.figure(figsize=(6,4))
plt.title('Revolver', fontdict={'fontweight':'bold'})
plt.xlabel('Danceability', fontsize=12)
plt.ylabel('Song', fontsize=12)

plt.scatter(revolver['danceability'], revolver['song'])

plt.show()

#finding highest danceability song from revolver dataframe
max = revolver ['danceability'].max()

maxdf = pd.concat([maxdf,revolver[revolver['danceability'] == max]])

#display top dance song
print('Dance Score:', max, ':', 'Good Day Sunshine')
print()



#creating new dataframe called rudder from df1
rudder = df1[df1['album'] == 'Rubber Soul']

#Rubber Soul Album showing dancability by song
plt.figure(figsize=(6,4))
plt.title('Rudder Soul', fontdict={'fontweight':'bold'})
plt.xlabel('Danceability', fontsize=12)
plt.ylabel('Song', fontsize=12)

plt.scatter(rudder['danceability'], rudder['song'])

plt.show()

#finding highest danceability song from rudder dataframe
max = rudder ['danceability'].max()

maxdf = pd.concat([maxdf,rudder[rudder['danceability'] == max]])

#display top dance song
print('Dance Score:', max, ':', 'Drive My Car')
print()



#creating new dataframe called help from df1
help = df1[df1['album'] == 'Help!']

#Help! Album showing dancability by song
plt.figure(figsize=(6,4))
plt.title('Help!', fontdict={'fontweight':'bold'})
plt.xlabel('Danceability', fontsize=12)
plt.ylabel('Song', fontsize=12)

plt.scatter(help['danceability'], help['song'])

plt.show()

#finding highest danceability song from help dataframe
max = help ['danceability'].max()

maxdf = pd.concat([maxdf,help[help['danceability'] == max]])

#display top dance song
print('Dance Score:', max, ':', 'Act Naturally')
print()



#creating new dataframe called sale from df1
sale = df1[df1['album'] == 'Beatles for Sale']

#Beatles for Sale Album showing dancability by song
plt.figure(figsize=(6,4))
plt.title('Beatles for Sale', fontdict={'fontweight':'bold'})
plt.xlabel('Danceability', fontsize=12)
plt.ylabel('Song', fontsize=12)

plt.scatter(sale['danceability'], sale['song'])

plt.show()

#finding highest danceability song from sale dataframe
max = sale ['danceability'].max()

maxdf = pd.concat([maxdf,sale[sale['danceability'] == max]])

#display top dance song
print('Dance Score:', max, ':', 'Every Little Thing')
print()



#creating new dataframe called hard from df1
hard = df1[df1['album'] == 'A Hard Day\'s Night']

#A Hard Day's Night Album showing dancability by song
plt.figure(figsize=(6,4))
plt.title('A Hard Day\'s Night', fontdict={'fontweight':'bold'})
plt.xlabel('Danceability', fontsize=12)
plt.ylabel('Song', fontsize=12)
plt.scatter(hard['danceability'], hard['song'])

plt.show()

#finding highest danceability song from hard dataframe
max = hard ['danceability'].max()

maxdf = pd.concat([maxdf,hard[hard['danceability'] == max]])

#display top dance song
print('Dance Score:', max, ':', 'And I Love Her')
print()



#creating new dataframe called wtb from df1
wtb = df1[df1['album'] == 'With The Beatles']

#With The Beatles Album showing dancability by song
plt.figure(figsize=(6,4))
plt.title('With The Beatles', fontdict={'fontweight':'bold'})
plt.xlabel('Danceability', fontsize=12)
plt.ylabel('Song', fontsize=12)

plt.scatter(wtb['danceability'], wtb['song'])

plt.show()

#finding highest danceability song from wtb dataframe
max = wtb ['danceability'].max()

maxdf = pd.concat([maxdf,wtb[wtb['danceability'] == max]])

#display top dance song
print('Dance Score:', max, ':', 'Till There Was You')
print()



#creating new dataframe called please from df1
please = df1[df1['album'] == 'Please Please Me']

#Please Please Me Album showing dancability by song
plt.figure(figsize=(6,4))
plt.title('Please Please Me', fontdict={'fontweight':'bold'})
plt.xlabel('Danceability', fontsize=12)
plt.ylabel('Song', fontsize=12)

plt.scatter(please['danceability'], please['song'])

plt.show()

#finding highest danceability song from please dataframe
max = please ['danceability'].max()

maxdf = pd.concat([maxdf,please[please['danceability'] == max]])

#display top dance song
print('Dance Score:', max, ':', 'Do You Want to Know a Secret')
print()



#new album showing all the highest danceability songs from each Beatle album called "Beatles Dance Hits" taken from maxdf dataframe
plt.figure(figsize=(10,8))
plt.title('Beatles Dance Hits', fontdict={'fontweight':'bold'})
plt.xlabel('Danceability', fontsize=12)
plt.ylabel('Song', fontsize=12)

#define x and y and color
x = np.array(maxdf['danceability'])
y = np.array(maxdf['song'])
c = ['#fa0000', '#f7e300', '#f78902', '#a9f700', '#19fc00', '#00fcf8', '#0535f5', '#262387', '#b300fa', '#5d2387', '#ffffff', '#808080', '#000000']

plt.scatter(maxdf['danceability'], maxdf['song'], color=c, s=500)

#showing Albums per color
plt.show()

title_color = 'Color'
title_album = 'Album'

#data under titles
df2 = pd.DataFrame({'Color': ['Red', 'Yellow', 'Orange', 'Light Green', 'Green', 'Light Blue', 'Blue', 'Dark Blue', 'Purple', 'Dark Purple', 'White', 'Gray', 'Black'],'Album': 
                   ['Let It Be', 'Abbey Road', 'Yellow Submarine', 'The Beatles (white album)', 'Magical Mystery Tour', 'Sgt. Pepper\'s Lonely Hearts Club Band', 'Revolver', 
                    'Rudder Soul', 'Help!', 'Beatles for Sale', 'A Hard Day\'s Night', 'With The Beatles', 'Please Please Me']})
print(df2)
print()


#plot showing danceability and energy correlation 

plt.figure(figsize=(22,16))
plt.title('Danceability and Energy correlation by individual song in Beatles Albums', fontdict={'fontweight':'bold'})
plt.xlabel('Energy', fontsize=12)
plt.ylabel('Danceability', fontsize=12)
plt.stem(letbe.energy, letbe.danceability, '#d11717', use_line_collection=True)
plt.stem(abbey.energy, abbey.danceability, '#d16b17', use_line_collection=True)
plt.stem(yellow.energy, yellow.danceability, '#b6cf19', use_line_collection=True)
plt.stem(white.energy, white.danceability, '#46cf19', use_line_collection=True)
plt.stem(magical.energy, magical.danceability, '#19cfbc', use_line_collection=True)
plt.stem(sgt.energy, sgt.danceability, '#1986cf', use_line_collection=True)
plt.stem(revolver.energy, revolver.danceability, '#192ecf', use_line_collection=True)
plt.stem(rudder.energy, rudder.danceability, '#5e19cf', use_line_collection=True)
plt.stem(help.energy, help.danceability, '#b319cf', use_line_collection=True)
plt.stem(sale.energy, sale.danceability, '#cf1971', use_line_collection=True)
plt.stem(hard.energy, hard.danceability, '#dba0a0', use_line_collection=True)
plt.stem(wtb.energy, wtb.danceability, '#a6dba0', use_line_collection=True)
plt.stem(please.energy, please.danceability, '#a0a7db', use_line_collection=True)

plt.show()
print()



####NOT USED####
#print(letbe.danceability)

#plt.figure(figsize=(12,10))
#plt.plot(maxdf.danceability, color = 'b')
#plt.plot(maxdf.energy, color = 'r')
#plt.show()
####NOT USED####



#Pie chart showing vocals percentages 
freq = {}

for vocals in df1['vocals']:
    if vocals in freq.keys():
        freq[vocals] += 1
    else:
        freq[vocals] = 1

freq1 = {}

plt.style.use('ggplot')
explode = (0,0,0,0,0,.6,.7,.8,.9)
plt.figure(figsize=(8,8))
plt.xlabel('nan = unavailable', fontsize=12)
plt.title('Vocals', fontdict={'fontweight':'bold'})
plt.pie(freq.values(), labels=freq.keys(), autopct='%.2f %%', pctdistance=0.5, explode=explode)
plt.show()
print()


#function to create a new pie plot showing percentages of songs by danceability 
df1.danceability = [int if type (x)==str else x for x in df1.danceability]

#define light, light_medium, medium and high show plots every song from .0 - .08 and sorts by danceability
light = df1[df1.danceability <.2].count()[0]
light_medium = df1[(df1.danceability >= .2) & (df1.danceability > .4)].count()[0]
medium = df1[(df1.danceability >= .4) & (df1.danceability < .6)].count()[0]
high = df1[(df1.danceability >= .6)].count()[0]

#pie plot showiing dancability by light, light_medium, medium, and high
danceability = [light, light_medium, medium, high]
labels = ['Under .2', '.2-.4', '.4-.6', 'over .6']
plt.figure(figsize=(8,8))
plt.title('Beatles Dance Hits', fontdict={'fontweight':'bold'})
explode = (.4,0,0,0)
plt.pie(danceability, labels=labels, autopct='%.2f %%', pctdistance=0.5, explode=explode)

plt.show()
print()



#calculating mean of danceability in df1 
mean = df1.mean()
print('danceability mean in dataframe')
print(mean['danceability'])
print()



#calculating median of danceability in df1 
median = df1.median()
print('danceability median in dataframe')
print(median['danceability'])
print()



#calculating mode of danceability in df1
mode=df1.mode()
print('danceability mode in dataframe')
print(mode['danceability'])
print()
# Out:
# Index(['id', 'year', 'album', 'song', 'danceability', 'energy', 'mode',
#        'speechiness', 'acousticness', 'liveness', 'valence', 'duration_ms',
#        'vocals'],
#       dtype='object')
# Index(['year', 'album', 'song', 'danceability', 'energy', 'vocals'], dtype='object')
# Dance Score: 0.88 : For You Blue
# Dance Score: 0.764 : Maxwells Silver Hammer
# Dance Score: 0.605 : Yellow Submarine
# Dance Score: 0.818 : Obi-la-di, Ob-la-da
# Dance Score: 0.698 : Your Mother Should Know
# Dance Score: 0.705 : With a Little Help from My Friends
# Dance Score: 0.77 : Good Day Sunshine
# Dance Score: 0.754 : Drive My Car
# Dance Score: 0.702 : Act Naturally
# Dance Score: 0.74 : Every Little Thing
# Dance Score: 0.767 : And I Love Her
# Dance Score: 0.727 : Till There Was You
# Dance Score: 0.673 : Do You Want to Know a Secret
#           Color                                  Album
# 0           Red                              Let It Be
# ...
